# %%
import pandas as pd
import numpy as np
import os

# %%
MyPath="/Users/Max/Documents/Text mining /Raw_text_speeches"

path = os.chdir(MyPath)
RemoveWords=["href", "class", "div", "block", "nav", "pagination","view","-text","Transcript"
             "space", "https", "http", "template", "squarespace", "id", "jpg", "image",
             "header", "function", "folder", 'drupal',"transcript","applause", "expandable",
            "<div class=view-transcript><div class=expandable-text> ","View Transcript","</p>","<p>",
             "< ","data-close-label=","<h3>","</h3>","-inner","-trigger","display: none;","Transcript",
            ">",">=","-","--","=", "</a", "<a","btn top","dataopenlabel","#dp","</",'""',"btn bottom","He ",
            "btn","container","dp","style",'"   ""','"" ""','"',"br/"]  
# Read text File
  
def read_text_file(file_path):
    with open(file_path, 'r') as f:
        text = f.read()
        text = text.split()
        spliced_text = " ".join(text)
        _text = spliced_text.replace(",", "")
        for i in RemoveWords:
            _text = _text.replace(i, "")
        return _text
  
  
filename="Transactions.csv"
MyFILE=open(filename,"w")  # "a"  for append   "r" for read
## with open
# WriteThis="LABEL\n"
# MyFILE.write(WriteThis)
### Place the column names in - write to the first row
MyFILE.close()
MyFILE=open(filename, "a")
for file in os.listdir():
    # Check whether file is in text format or not
    if file.endswith(".txt"):
        file_path = "/Users/Max/Documents/Text mining /Raw_text_speeches"+"/"+file
  
        # call read text file function
#         read_text_file(file_path)
        LABEL=read_text_file(file_path)
        WriteThis= str(LABEL)+ "\n"
#         print(WriteThis)
        MyFILE.write(WriteThis)
MyFILE.close()

# %%
MyPath="/Users/Max/Documents/Text mining /Raw_text_speeches"

path = os.chdir(MyPath)
RemoveWords=["href", "class", "div", "block", "nav", "pagination","view","-text","Transcript"
             "space", "https", "http", "template", "squarespace", "id", "jpg", "image",
             "header", "function", "folder", 'drupal',"transcript","applause", "expandable",
            "<div class=view-transcript><div class=expandable-text> ","View Transcript","</p>","<p>",
             "< ","data-close-label=","<h3>","</h3>","-inner","-trigger","display: none;","Transcript",
            ">",">=","-","--","=", "</a", "<a","btn top","dataopenlabel","#dp","</",'""',"btn bottom","He ",
            "btn","container","dp","style",'"   ""','"" ""','"',"br/"]  
# Read text File
  
def read_text_file(file_path):
    with open(file_path, 'r') as f:
        text = f.read()
        text = text.split()
        spliced_text = " ".join(text)
        _text = spliced_text.replace(",", "")
        for i in RemoveWords:
            _text = _text.replace(i, "")
        return _text

for file in os.listdir():
    # Check whether file is in text format or not
    if file.endswith(".txt"):
        file_path = "/Users/Max/Documents/Text mining /Raw_text_speeches"+"/"+file
  
        # call read text file function
#         read_text_file(file_path)
        text=read_text_file(file_path)
    with open('/Users/Max/Documents/Text mining /Cleaned_speech_Data/'+file+'.txt', 'w') as f:
            f.write(text)
f.close()

# %%
MyPath="/Users/Max/Documents/Text mining /Raw_text_speeches_Coded_President_Parties/"

path = os.chdir(MyPath)
RemoveWords=["href", "class", "div", "block", "nav", "pagination","view","-text","Transcript"
             "space", "https", "http", "template", "squarespace", "id", "jpg", "image",
             "header", "function", "folder", 'drupal',"transcript","applause", "expandable",
            "<div class=view-transcript><div class=expandable-text> ","View Transcript","</p>","<p>",
             "< ","data-close-label=","<h3>","</h3>","-inner","-trigger","display: none;","Transcript",
            ">",">=","-","--","=", "</a", "<a","btn top","dataopenlabel","#dp","</",'""',"btn bottom","He ",
            "btn","container","dp","style",'"   ""','"" ""','"',"br/"]  
# Read text File
  
def read_text_file(file_path):
    with open(file_path, 'r') as f:
        text = f.read()
        text = text.split()
        spliced_text = " ".join(text)
        _text = spliced_text.replace(",", "")
        for i in RemoveWords:
            _text = _text.replace(i, "")
        return _text
  
for folderName in ['Republican', 'Whig', 'Democrat', 'Democratic-Republican', 'Federalist']:
    ## Get the files 
    filenames=os.listdir(MyPath + folderName)  
    filename=folderName+"_Transactions.csv"
    MyFILE=open(filename,"w")  # "a"  for append   "r" for read
    ## with open
    # WriteThis="LABEL\n"
    # MyFILE.write(WriteThis)
    ### Place the column names in - write to the first row
    MyFILE.close()
    MyFILE=open(filename, "a")
    for file in filenames:
        # Check whether file is in text format or not
        if file.endswith(".txt"):
            file_path = "/Users/Max/Documents/Text mining /Raw_text_speeches_Coded_President_Parties/"+folderName+"/"+file

            # call read text file function
    #         read_text_file(file_path)
            LABEL=read_text_file(file_path)
            WriteThis= str(LABEL)+ "\n"
    #         print(WriteThis)
            MyFILE.write(WriteThis)
    MyFILE.close()
